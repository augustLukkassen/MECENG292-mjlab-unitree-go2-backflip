# %%
import subprocess
import sys

process = subprocess.Popen(
  [
    "uvx",
    "--refresh",
    "--from",
    "mjlab==0.1.0",
    "--with",
    "mujoco-warp @ git+https://github.com/google-deepmind/mujoco_warp@486642c3fa262a989b482e0e506716d5793d61a9",
    "demo",
  ],
  stdout=subprocess.PIPE,
  stderr=subprocess.STDOUT,
  universal_newlines=True,
  bufsize=1,
)

for line in process.stdout:
  print(line, end="")
  sys.stdout.flush()

  if "serving" in line.lower() or "running on" in line.lower() or "8081" in line:
    print("\n" + "=" * 50)
    print("✅ Server is running! Execute the next cell to view.")
    print("=" * 50)
    break
# Out:
# Installed 120 packages in 1.37s
# Warp DeprecationWarning: The namespace `warp.context` will soon be removed from the public API. It can still be accessed from `warp._src.context` but might be changed or removed without notice.
# Warp DeprecationWarning: The symbol `warp.context.Module` will soon be removed from the public API. Use `warp.Module` instead.
# Warp DeprecationWarning: The symbol `warp.context.assert_conditional_graph_support` will soon be removed from the public API. It can still be accessed from `warp._src.context.assert_conditional_graph_support` but might be changed or removed without notice.
# Warp DeprecationWarning: The symbol `warp.context.get_module` will soon be removed from the public API. Use `warp.get_module` instead.
# Warp DeprecationWarning: The namespace `warp.math` will soon be removed from the public API. It can still be accessed from `warp._src.math` but might be changed or removed without notice.
# 🎮 Setting up MJLab demo with pretrained tracking policy...
# 📥 Downloading demo_ckpt.pt...
#
# demo_ckpt.pt:   0%|          | 0.00/7.39M [00:00<?, ?B/s]
# demo_ckpt.pt: 100%|██████████| 7.39M/7.39M [00:00<00:00, 99.2MB/s]
# ✅ demo_ckpt.pt cached at /tmp/mjlab_cache/demo_ckpt.pt
# 📥 Downloading demo_motion.npz...
#
# demo_motion.npz:   0%|          | 0.00/11.2M [00:00<?, ?B/s]
# demo_motion.npz: 100%|██████████| 11.2M/11.2M [00:00<00:00, 120MB/s]
# Warp CUDA warning: Could not find or load the NVIDIA CUDA driver. Proceeding in CPU-only mode.
# ✅ demo_motion.npz cached at /tmp/mjlab_cache/demo_motion.npz
# [INFO]: Using device: cpu
# [INFO]: Parsing configuration from: mjlab.tasks.tracking.config.g1.flat_env_cfg:G1FlatEnvCfg_PLAY
# [INFO]: Parsing configuration from: mjlab.tasks.tracking.config.g1.rl_cfg:G1FlatPPORunnerCfg
# [INFO]: Loading experiment from: /content/logs/rsl_rl/g1_tracking
# [INFO]: Loading checkpoint: /tmp/mjlab_cache/demo_ckpt.pt
# [INFO]: Using motion file from CLI: /tmp/mjlab_cache/demo_motion.npz
# No seed set for the environment.
# [INFO]: Scene manager: <mjlab.scene.scene.Scene object at 0x78722e4c08c0>
# Warp 1.11.0.dev20251218 initialized:
#    Git commit: 171d5555a529717f7e422870c2ccd67fafe47fd1
#    CUDA driver not found or failed to initialize
#    Devices:
#      "cpu"      : "x86_64"
#    Kernel cache:
#      /root/.cache/warp/1.11.0.dev20251218
# [INFO]: Base environment:
# 	Environment device    : cpu
# 	Environment seed      : None
# 	Physics step-size     : 0.005
# 	Environment step-size : 0.02
# [INFO] Command Manager: <CommandManager> contains 1 active terms.
# +--------------------------------+
# |      Active Command Terms      |
# +-------+--------+---------------+
# | Index | Name   |      Type     |
# +-------+--------+---------------+
# |   0   | motion | MotionCommand |
# +-------+--------+---------------+
#
# [INFO] Event manager: <EventManager> contains 1 active terms.
# +---------------------------------------+
# | Active Event Terms in Mode: 'startup' |
# +--------+------------------------------+
# | Index  | Name                         |
# +--------+------------------------------+
# |   0    | base_com                     |
# |   1    | add_joint_default_pos        |
# |   2    | foot_friction                |
# +--------+------------------------------+
# +-----------------------------+
# | Domain Randomization Fields |
# +--------+--------------------+
# | Index  | Field Name         |
# +--------+--------------------+
# |   0    | body_ipos          |
# |   1    | qpos0              |
# |   2    | geom_friction      |
# +--------+--------------------+
#
# Module repeat_array_kernel_8155c5c0 a976a41 load on device 'cpu' took 2422.18 ms  (compiled)
# Module repeat_array_kernel_8155c5c0 0210052 load on device 'cpu' took 2650.63 ms  (compiled)
# [INFO] Action Manager: <ActionManager> contains 1 active terms.
# +---------------------------------+
# | Active Action Terms (shape: 29) |
# +-------+-----------+-------------+
# | Index | Name      |   Dimension |
# +-------+-----------+-------------+
# |   0   | joint_pos |          29 |
# +-------+-----------+-------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 2 groups.
# +-------------------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (160,)) |
# +-----------+------------------------------------+------------+
# |   Index   | Name                               |   Shape    |
# +-----------+------------------------------------+------------+
# |     0     | command                            |   (58,)    |
# |     1     | motion_anchor_pos_b                |    (3,)    |
# |     2     | motion_anchor_ori_b                |    (6,)    |
# |     3     | base_lin_vel                       |    (3,)    |
# |     4     | base_ang_vel                       |    (3,)    |
# |     5     | joint_pos                          |   (29,)    |
# |     6     | joint_vel                          |   (29,)    |
# |     7     | actions                            |   (29,)    |
# +-----------+------------------------------------+------------+
# +-------------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (286,)) |
# +-----------+------------------------------------+------------+
# |   Index   | Name                               |   Shape    |
# +-----------+------------------------------------+------------+
# |     0     | command                            |   (58,)    |
# |     1     | motion_anchor_pos_b                |    (3,)    |
# |     2     | motion_anchor_ori_b                |    (6,)    |
# |     3     | body_pos                           |   (42,)    |
# |     4     | body_ori                           |   (84,)    |
# |     5     | base_lin_vel                       |    (3,)    |
# |     6     | base_ang_vel                       |    (3,)    |
# |     7     | joint_pos                          |   (29,)    |
# |     8     | joint_vel                          |   (29,)    |
# |     9     | actions                            |   (29,)    |
# +-----------+------------------------------------+------------+
#
# [INFO] Termination Manager: <TerminationManager> contains 4 active terms.
# +--------------------------------+
# |    Active Termination Terms    |
# +-------+-------------+----------+
# | Index | Name        | Time Out |
# +-------+-------------+----------+
# |   0   | time_out    |   True   |
# |   1   | anchor_pos  |  False   |
# |   2   | anchor_ori  |  False   |
# |   3   | ee_body_pos |  False   |
# +-------+-------------+----------+
#
# [INFO] Reward Manager: <RewardManager> contains 9 active terms.
# +-----------------------------------------+
# |           Active Reward Terms           |
# +-------+------------------------+--------+
# | Index | Name                   | Weight |
# +-------+------------------------+--------+
# |   0   | motion_global_root_pos |    0.5 |
# |   1   | motion_global_root_ori |    0.5 |
# |   2   | motion_body_pos        |    1.0 |
# |   3   | motion_body_ori        |    1.0 |
# |   4   | motion_body_lin_vel    |    1.0 |
# |   5   | motion_body_ang_vel    |    1.0 |
# |   6   | action_rate_l2         |   -0.1 |
# |   7   | joint_limit            |  -10.0 |
# |   8   | self_collisions        |  -10.0 |
# +-------+------------------------+--------+
#
# [INFO] Curriculum Manager: <NullCurriculumManager> (inactive)
# [INFO]: Completed setting up the environment...
# Module mujoco_warp._src.smooth 1f725c3 load on device 'cpu' took 6221.16 ms  (compiled)
# Module mujoco_warp._src.collision_driver efeb855 load on device 'cpu' took 2124.37 ms  (compiled)
# Module _nxn_broadphase__locals__kernel_726727ea 202d79f load on device 'cpu' took 2976.67 ms  (compiled)
# Module _create_narrowphase_kernel__locals___primitive_narrowphase_75783b2a ec601f8 load on device 'cpu' took 2752.48 ms  (compiled)
# Module mujoco_warp._src.constraint 3a37206 load on device 'cpu' took 3754.10 ms  (compiled)
# Module mujoco_warp._src.forward 77352f0 load on device 'cpu' took 2699.66 ms  (compiled)
# Module _create_actuator_velocity_kernel__locals__actuator_velocity_68e06237 c2a7d4d load on device 'cpu' took 2776.31 ms  (compiled)
# Module mujoco_warp._src.passive 5204b2f load on device 'cpu' took 3021.71 ms  (compiled)
# Module mujoco_warp._src.support 27a5bec load on device 'cpu' took 2363.39 ms  (compiled)
# Module _tile_cholesky_factorize_solve__locals__cholesky_factorize_solve_29dc48ce 18e97b7 load on device 'cpu' took 2287.66 ms  (compiled)
# Module mujoco_warp._src.solver 47dcba3 load on device 'cpu' took 4220.12 ms  (compiled)
# Module mul_m_dense__locals__kernel_43447229 29ff949 load on device 'cpu' took 2192.75 ms  (compiled)
# Module update_constraint_gauss_cost__locals__kernel_bfef4d5b 108d9ae load on device 'cpu' took 2079.63 ms  (compiled)
# Module update_gradient_cholesky_blocked__locals__kernel_112c648b 59d28cb load on device 'cpu' took 3075.24 ms  (compiled)
# Module linesearch_jv_fused__locals__kernel_3315b432 2b79529 load on device 'cpu' took 2389.92 ms  (compiled)
# Module mujoco_warp._src.sensor bee9c06 load on device 'cpu' took 6188.74 ms  (compiled)
# Module _contact_sort__locals__contact_sort_e882758a ab58188 load on device 'cpu' took 2187.75 ms  (compiled)
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 policy :  ['policy']
# 	 critic :  ['policy', 'critic']
# --------------------------------------------------------------------------------
# Actor MLP: MLP(
#   (0): Linear(in_features=160, out_features=512, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=512, out_features=256, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=256, out_features=128, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=128, out_features=29, bias=True)
# )
# Critic MLP: MLP(
#   (0): Linear(in_features=446, out_features=512, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=512, out_features=256, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Linear(in_features=256, out_features=128, bias=True)
#   (5): ELU(alpha=1.0)
#   (6): Linear(in_features=128, out_features=1, bias=True)
# )
# Traceback (most recent call last):
#   File "/root/.cache/uv/archive-v0/eIw-MiZ_OhSb8PquYve2N/bin/demo", line 12, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/root/.cache/uv/archive-v0/eIw-MiZ_OhSb8PquYve2N/lib/python3.12/site-packages/mjlab/scripts/demo.py", line 27, in main
#     tyro.cli(
#   File "/root/.cache/uv/archive-v0/eIw-MiZ_OhSb8PquYve2N/lib/python3.12/site-packages/tyro/_cli.py", line 281, in cli
#     out = run_with_args_from_cli()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/.cache/uv/archive-v0/eIw-MiZ_OhSb8PquYve2N/lib/python3.12/site-packages/mjlab/scripts/play.py", line 108, in run_play
#     runner = MotionTrackingOnPolicyRunner(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/.cache/uv/archive-v0/eIw-MiZ_OhSb8PquYve2N/lib/python3.12/site-packages/mjlab/tasks/tracking/rl/runner.py", line 25, in __init__
#     super().__init__(env, train_cfg, log_dir, device)
#   File "/root/.cache/uv/archive-v0/eIw-MiZ_OhSb8PquYve2N/lib/python3.12/site-packages/rsl_rl/runners/on_policy_runner.py", line 49, in __init__
#     self.logger = Logger(
#                   ^^^^^^^
#   File "/root/.cache/uv/archive-v0/eIw-MiZ_OhSb8PquYve2N/lib/python3.12/site-packages/rsl_rl/utils/logger.py", line 61, in __init__
#     self._prepare_logging_writer()
#   File "/root/.cache/uv/archive-v0/eIw-MiZ_OhSb8PquYve2N/lib/python3.12/site-packages/rsl_rl/utils/logger.py", line 249, in _prepare_logging_writer
#     self.writer = WandbSummaryWriter(log_dir=self.log_dir, flush_secs=10, cfg=self.cfg)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/.cache/uv/archive-v0/eIw-MiZ_OhSb8PquYve2N/lib/python3.12/site-packages/rsl_rl/utils/wandb_utils.py", line 38, in __init__
#     wandb.init(project=project, entity=entity, name=run_name)
#   File "/root/.cache/uv/archive-v0/eIw-MiZ_OhSb8PquYve2N/lib/python3.12/site-packages/wandb/sdk/wandb_init.py", line 1594, in init
#     get_sentry().reraise(e)
#   File "/root/.cache/uv/archive-v0/eIw-MiZ_OhSb8PquYve2N/lib/python3.12/site-packages/wandb/analytics/sentry.py", line 190, in reraise
#     raise exc.with_traceback(tb)
#   File "/root/.cache/uv/archive-v0/eIw-MiZ_OhSb8PquYve2N/lib/python3.12/site-packages/wandb/sdk/wandb_init.py", line 1515, in init
#     wi.maybe_login(init_settings)
#   File "/root/.cache/uv/archive-v0/eIw-MiZ_OhSb8PquYve2N/lib/python3.12/site-packages/wandb/sdk/wandb_init.py", line 192, in maybe_login
#     wandb_login._login(
#   File "/root/.cache/uv/archive-v0/eIw-MiZ_OhSb8PquYve2N/lib/python3.12/site-packages/wandb/sdk/wandb_login.py", line 365, in _login
#     key, key_status = wlogin.prompt_api_key(referrer=referrer)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/.cache/uv/archive-v0/eIw-MiZ_OhSb8PquYve2N/lib/python3.12/site-packages/wandb/sdk/wandb_login.py", line 272, in prompt_api_key
#     raise UsageError(message) from None
# wandb.errors.errors.UsageError: No API key configured. Use `wandb login` to log in.

# %%
from google.colab import output

output.serve_kernel_port_as_iframe(8081)
